# %% [markdown]
# # funciones un SGBD tiene el trabajo de crear las descripcion, manipulacion y utilizacion de los datos mediante:
#
# - DDL: mediante este se generan la estrucutra de datos (tables) se definen relaciones entre ellas, tambien las reglas y restricciones
#
# ![image.png](attachment:image.png)
#
# - DML: permite a los usuarios la busqueda insercion, eliminacio o modificacion de los datos cuidando las normas de seguiridad
#
# ![image-2.png](attachment:image-2.png)
#
# - DCL: Permite que el admin pueda proteger
