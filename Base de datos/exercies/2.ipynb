# %% [markdown]
# Obligatorio
# univaluado
#
#
# obligatorio
# multivaluado
#
# opcional
#  univaluado
#
# opcional
#  multivaluado
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# el calculado se hace con redondeado el circulo

# %% [markdown]
# ![image.png](attachment:image.png)
#
# la clave va rellena del todo solo debemos tener una PRIMARY KEY

# %% [markdown]
# ![image.png](attachment:image.png)
#
# LA clave candidata solo va rellena a la mitad de color
